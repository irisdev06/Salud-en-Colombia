# %% [markdown]
# ## Importaciones

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt

PRESA01 = pd.read_csv("datos/SA_DATA.csv")
PRESA01.head()
# Out:
#         GHO (CODE)                          GHO (DISPLAY)  \
# 0  #indicator+code                        #indicator+name
# 1         WHS6_102  Hospital beds (per 10 000 population)
# 2         WHS6_102  Hospital beds (per 10 000 population)
# 3         WHS6_102  Hospital beds (per 10 000 population)
# 4         WHS6_102  Hospital beds (per 10 000 population)
#
#                                            GHO (URL) YEAR (DISPLAY)  \
# 0                                     #indicator+url     #date+year
# 1  https://www.who.int/data/gho/data/indicators/i...           2014
# 2  https://www.who.int/data/gho/data/indicators/i...           2020
# 3  https://www.who.int/data/gho/data/indicators/i...           2019
# 4  https://www.who.int/data/gho/data/indicators/i...           2017
#
#           STARTYEAR         ENDYEAR REGION (CODE) REGION (DISPLAY)  \
# 0  #date+year+start  #date+year+end  #region+code     #region+name
# 1              2014            2014           AMR         Americas
# ...

# %% [markdown]
# # Exploración Inicial de los Datos 🔎
# Para analizar la información de mi dataset, su tamaño y las columnas.

# %%
PRESA01.info()
PRESA01.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 17 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   GHO (CODE)         12 non-null     object
#  1   GHO (DISPLAY)      12 non-null     object
#  2   GHO (URL)          12 non-null     object
#  3   YEAR (DISPLAY)     12 non-null     object
#  4   STARTYEAR          12 non-null     object
#  5   ENDYEAR            12 non-null     object
#  6   REGION (CODE)      12 non-null     object
#  7   REGION (DISPLAY)   12 non-null     object
#  8   COUNTRY (CODE)     12 non-null     object
#  9   COUNTRY (DISPLAY)  12 non-null     object
#  10  DIMENSION (TYPE)   1 non-null      object
#  11  DIMENSION (CODE)   1 non-null      object
#  12  DIMENSION (NAME)   1 non-null      object
#  13  Numeric            12 non-null     object
#  14  Value              12 non-null     object
#  15  Low                1 non-null      object
# ...

# %%
PRESA01.head()
# Out:
#         GHO (CODE)                          GHO (DISPLAY)  \
# 0  #indicator+code                        #indicator+name
# 1         WHS6_102  Hospital beds (per 10 000 population)
# 2         WHS6_102  Hospital beds (per 10 000 population)
# 3         WHS6_102  Hospital beds (per 10 000 population)
# 4         WHS6_102  Hospital beds (per 10 000 population)
#
#                                            GHO (URL) YEAR (DISPLAY)  \
# 0                                     #indicator+url     #date+year
# 1  https://www.who.int/data/gho/data/indicators/i...           2014
# 2  https://www.who.int/data/gho/data/indicators/i...           2020
# 3  https://www.who.int/data/gho/data/indicators/i...           2019
# 4  https://www.who.int/data/gho/data/indicators/i...           2017
#
#           STARTYEAR         ENDYEAR REGION (CODE) REGION (DISPLAY)  \
# 0  #date+year+start  #date+year+end  #region+code     #region+name
# 1              2014            2014           AMR         Americas
# ...

# %% [markdown]
# ### Información contenida en el dataset:
# - **GHO (CODE)**: `WHS6_102` - Código del indicador (número de camas hospitalarias por cada 10,000 habitantes).
# - **GHO (DISPLAY)**: `Hospital beds (per 10 000 population)` - Descripción del indicador.
# - **YEAR (DISPLAY)**: `2014` - El año en que se reportó el dato.
# - **STARTYEAR** y **ENDYEAR**: `2014` - El periodo de tiempo en el que se tomó la medición.
# - **REGION (CODE)**: `AMR` - América (Américas).
# - **COUNTRY (CODE)**: `COL` - Colombia.
# - **Numeric**: `16.25071` - Valor numérico preciso de camas hospitalarias por cada 10,000 habitantes.
# - **Value**: `16.3` - Valor redondeado del indicador.
# - **Low** y **High**: `NaN` - No se proporcionan rangos en este caso.

# %% [markdown]
# ### Buscando valores nulos

# %%
valoresnull = PRESA01.isnull().sum()
valoresnull
# Out:
# GHO (CODE)            0
# GHO (DISPLAY)         0
# GHO (URL)             0
# YEAR (DISPLAY)        0
# STARTYEAR             0
# ENDYEAR               0
# REGION (CODE)         0
# REGION (DISPLAY)      0
# COUNTRY (CODE)        0
# COUNTRY (DISPLAY)     0
# DIMENSION (TYPE)     11
# DIMENSION (CODE)     11
# DIMENSION (NAME)     11
# Numeric               0
# Value                 0
# Low                  11
# High                 11
# dtype: int64

# %% [markdown]
# Para conocer el porcentaje de valores nulos por columna.

# %%
nvalorespct = PRESA01.isnull().mean() * 100
nvalorespct
# Out:
# GHO (CODE)            0.000000
# GHO (DISPLAY)         0.000000
# GHO (URL)             0.000000
# YEAR (DISPLAY)        0.000000
# STARTYEAR             0.000000
# ENDYEAR               0.000000
# REGION (CODE)         0.000000
# REGION (DISPLAY)      0.000000
# COUNTRY (CODE)        0.000000
# COUNTRY (DISPLAY)     0.000000
# DIMENSION (TYPE)     91.666667
# DIMENSION (CODE)     91.666667
# DIMENSION (NAME)     91.666667
# Numeric               0.000000
# Value                 0.000000
# Low                  91.666667
# High                 91.666667
# dtype: float64

# %% [markdown]
# - **"DIMENSION (TYPE)", "DIMENSION (CODE)", "DIMENSION (NAME)":** Tienen 91.67% de valores nulos, lo que significa que casi todo el contenido de estas columnas está vacío.
# - **"Low" y "High":** Tienen un 91.67% de valores nulos. Esto sugiere que en la mayoría de los casos no se tiene información sobre el rango de valores, lo cual podría ser relevante dependiendo del tipo de análisis que quieras realizar. **Estas columnas están relacionadas entre sí.** Podemos observar que el porcentaje de **valores faltantes es el mismo** y aparte, el contenido e información que nos proporciona, se relaciona entre dichas columnas.
# - Las demás columnas **NO** tienen valores nulos.

# %% [markdown]
# # Limpiando los Datos 🧹
# Decidí no incluir las columnas:
# **"GHO (URL)" =** Es el url del código del indicador y no afecta en nada su eliminación.
# **"DIMENSION (CODE)", "DIMENSION (NAME)", "Low", "High" =** Columnas relacionadas entre sí que tienen el 91% de los datos nulos.
# Y eliminé el index 0, ya que era texto de guía.

# %%
INDEX = PRESA01.drop(0)
SA01 = INDEX.drop(columns=["GHO (URL)", "DIMENSION (TYPE)",  "DIMENSION (CODE)", "DIMENSION (NAME)", "Low", "High"])
SA01.head(20)
# Out:
#    GHO (CODE)                          GHO (DISPLAY) YEAR (DISPLAY) STARTYEAR  \
# 1    WHS6_102  Hospital beds (per 10 000 population)           2014      2014
# 2    WHS6_102  Hospital beds (per 10 000 population)           2020      2020
# 3    WHS6_102  Hospital beds (per 10 000 population)           2019      2019
# 4    WHS6_102  Hospital beds (per 10 000 population)           2017      2017
# 5    WHS6_102  Hospital beds (per 10 000 population)           2012      2012
# 6    WHS6_102  Hospital beds (per 10 000 population)           2015      2015
# 7    WHS6_102  Hospital beds (per 10 000 population)           2016      2016
# 8    WHS6_102  Hospital beds (per 10 000 population)           2018      2018
# 9    WHS6_102  Hospital beds (per 10 000 population)           2013      2013
# 10   WHS6_102  Hospital beds (per 10 000 population)           2011      2011
# 11   WHS6_102  Hospital beds (per 10 000 population)           2010      2010
#
# ...

# %% [markdown]
# # Analisis
# Número de camas por año, para analizar cómo ha incrementado.

# %%
año_camas_sum = SA01.groupby("STARTYEAR")["Numeric"].sum()
año_camas_sum = pd.to_numeric(año_camas_sum, errors='coerce')


plt.figure(figsize=(20, 6))
plt.plot(año_camas_sum.index, año_camas_sum.values, marker='o', linestyle='-', color='purple')
plt.xticks(rotation=90)
plt.title('Suma de los valores por año', fontsize=16)
plt.xlabel('Año', fontsize=12)
plt.ylabel('Camas', fontsize=12)
plt.grid(True)
plt.yticks(np.arange(min(año_camas_sum.values), max(año_camas_sum.values) + 0.5, 0.25))
plt.show()

# %% [markdown]
# prueba
